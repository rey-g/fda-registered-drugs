# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import json
import os
import re

# %%
from collections import Counter
from itertools import chain

# %% [markdown]
# # Preliminaries
# ## Directories

# %%
# create directory for outputs
if not(os.path.exists('maps')):
    os.mkdir('maps')

# %% [markdown]
# ## Load dataset
# Data downloaded from FDA website: [link](https://verification.fda.gov.ph/drug_productslist.php)

# %%
f = pd.read_csv('drug_products.csv')
f.head(3)
# Out:
#   Registration Number                                       Generic Name  \
# 0           BR-041-03                                  Enoxaparin Sodium
# 1             BR-1000  Japanese Encephalitis Virus (Live, Attenuated,...
# 2             BR-1001             Phospholipid Fraction from Bovine Lung
#
#       Brand Name                                    Dosage Strength  \
# 0  Enoxbicare-40  4000 IU Anti-Factor Xa (equivalent to 40 mg) /...
# 1         IMOJEV              4.0-5.8 log 10 PFU** per dose (0.5mL)
# 2      Alveofact                            45 mg/mL (54 mg/1.2 mL)
#
#                                          Dosage Form          Classification  \
# 0                        Solution For Injection (SC)  Prescription Drug (RX)
# 1                     Suspension for Injection (S.C)  Prescription Drug (RX)
# 2  Lyophilized Powder for \r\nSuspension for Intr...  Prescription Drug (RX)
#
#                                            Packaging  \
# 0  0.4 mL in 1 mL pre-filled syringe (Box of 1 Bl...
# 1  Type I borosilicate glass vial with vvm contai...
# 2                 Blister pack x 10's (Box of 100's)
#
#                                         Manufacturer Country of Origin  \
# 0                            Brawn Laboratories Ltd.             India
# 1  Government Pharmaceutical Organization-Merieux...          Thailand
# 2                               BAG Health Care GmbH           Germany
#
#                               Trader                          Importer  \
# 0                                NaN  Ambica International Corporation
# 1  Sanofi Pasteur Limited - Thailand                    SANOFI PASTEUR
# 2                                NaN       Glorious Dexa Mandaya, Inc.
#
#                      Distributor       Expiry Date
# 0  Ambicare Pharmaceuticals Inc.  09 December 2025
# 1     Zuellig Pharma Corporation  16 December 2020
# 2    Glorious Dexa Mandaya, Inc.   06 January 2025

# %% [markdown]
# # Drug Classification
# OTC vs Rx vs HR

# %%
c = Counter(f['Classification'])
c
# Out:
# Counter({'Prescription Drug (RX)': 19070,
#          'Prescription Drug (Rx)': 3783,
#          'Prescription Drugs (RX)': 1,
#          'Solution for \r\nInjection (SC)': 1,
#          'Over-the-Counter (OTC) Drug': 577,
#          'Over-the-Counter (OTC)': 2556,
#          'Over-The-Counter (OTC)': 1378,
#          'Rx': 1,
#          'Household Remedy (HR)': 1657,
#          'Over-The-Counter (OTC) Drug': 46,
#          'Over-the-counter (OTC) Drug': 44,
#          nan: 3,
#          'Prescription Drug (RX) Drug': 5,
#          'Over The Counter (OTC) Drug': 1,
#          'Prescription drug (Rx)': 1,
#          'prescription Drug (Rx)': 1,
#          'Over-the-Counter Drug (OTC)': 2,
#          'Over-the Counter (OTC) Drug': 1,
#          'Over-The-Counter(OTC)': 16,
#          'None': 2,
#          'Prescription (Rx) Drug': 1,
#          'Over-the-Counter (OTC) drug': 1,
#          'Over-the-Counter (OTC) Drug :': 1,
#          'Over-The Counter (OTC)': 1,
#          'Prescription Drug (Rx': 1,
#          'Over-the-counter (OTC)': 1,
#          'Over-the-Counter (OTC)Drug': 1,
#          'HouseHold Remedy (HR)': 4,
#          'Traditionally-Used Herbal Product': 1})

# %%
def new_class(old_value):
    
    if pd.isnull(old_value):
        return None
    if re.search(r'.*(none).*', old_value.lower()):
        return None
    
    if re.search(r'.*(rx|prescr|inj).*', old_value.lower()):
        return 'Prescription Drug (Rx)'
    
    if re.search(r'.*(otc).*', old_value.lower()):
        return 'Over-the-Counter (OTC) Drug'
    
    if re.search(r'.*(household).*', old_value.lower()):
        return 'Household Remedy (HR)'

# %% [markdown]
# ## Output map

# %%
class_map = pd.DataFrame(columns=['original','new'])
class_map['original'] = c.keys()

# %%
class_map['new'] = class_map['original'].apply(new_class)
class_map
# Out:
#                              original                          new
# 0              Prescription Drug (RX)       Prescription Drug (Rx)
# 1              Prescription Drug (Rx)       Prescription Drug (Rx)
# 2             Prescription Drugs (RX)       Prescription Drug (Rx)
# 3     Solution for \r\nInjection (SC)       Prescription Drug (Rx)
# 4         Over-the-Counter (OTC) Drug  Over-the-Counter (OTC) Drug
# 5              Over-the-Counter (OTC)  Over-the-Counter (OTC) Drug
# 6              Over-The-Counter (OTC)  Over-the-Counter (OTC) Drug
# 7                                  Rx       Prescription Drug (Rx)
# 8               Household Remedy (HR)        Household Remedy (HR)
# 9         Over-The-Counter (OTC) Drug  Over-the-Counter (OTC) Drug
# 10        Over-the-counter (OTC) Drug  Over-the-Counter (OTC) Drug
# 11                                NaN                         None
# 12        Prescription Drug (RX) Drug       Prescription Drug (Rx)
# 13        Over The Counter (OTC) Drug  Over-the-Counter (OTC) Drug
# 14             Prescription drug (Rx)       Prescription Drug (Rx)
# 15             prescription Drug (Rx)       Prescription Drug (Rx)
# 16        Over-the-Counter Drug (OTC)  Over-the-Counter (OTC) Drug
# 17        Over-the Counter (OTC) Drug  Over-the-Counter (OTC) Drug
# 18              Over-The-Counter(OTC)  Over-the-Counter (OTC) Drug
# 19                               None                         None
# 20             Prescription (Rx) Drug       Prescription Drug (Rx)
# 21        Over-the-Counter (OTC) drug  Over-the-Counter (OTC) Drug
# 22      Over-the-Counter (OTC) Drug :  Over-the-Counter (OTC) Drug
# 23             Over-The Counter (OTC)  Over-the-Counter (OTC) Drug
# 24              Prescription Drug (Rx       Prescription Drug (Rx)
# 25             Over-the-counter (OTC)  Over-the-Counter (OTC) Drug
# 26         Over-the-Counter (OTC)Drug  Over-the-Counter (OTC) Drug
# 27              HouseHold Remedy (HR)        Household Remedy (HR)
# 28  Traditionally-Used Herbal Product                         None

# %%
class_map.to_csv('maps/classes.csv',index=False)

# %% [markdown]
# # Dosage Form
# Describe dosage forms. Too tedious to find all possible combinations.

# %%
print(f['Dosage Form'].nunique(dropna=False))
Counter(f['Dosage Form'])
# Out:
# 2252
# Counter({'Solution For Injection (SC)': 68,
#          'Suspension for Injection (S.C)': 1,
#          'Lyophilized Powder for \r\nSuspension for Intratracheal Administration': 1,
#          'Solution for Injection (I.V./S.C.)': 13,
#          'Solution for Injection (IV/SC)': 131,
#          'Solution For Injection (Im/Iv/Sc)': 18,
#          'Suspension For Injection (SC)': 7,
#          'Suspension For Injection': 11,
#          'Solution for injection': 3,
#          'Suspension for injection (SC)': 1,
#          'Solution For Injection (I.V. / S.C.)': 2,
#          'Solution For Injection (I.V./S.C.)': 8,
#          'Suspension for Injection (IM)': 22,
#          'Concentrated Solution for IV Infusion': 2,
#          'Solution for Injection': 103,
#          'Solution for Injection (IM/SC)': 8,
#          'Solution for Injection (SC)': 80,
#          'Concentrate for Solution for Infusion (IV)': 9,
#          'Solution for Subcutaneous/Continuous SC Pump Infusion/ \r\nIntravenous Injection': 1,
#          'Powder for Concentrate Solution for I.V. Infusion': 1,
#          'Powder for Concentrate Sol ution for I. V. Infusion': 1,
#          'Lyophilized Powder for Solution for Subcutaneous Injection': 1,
#          'Solution for Intravenous Infusion': 78,
#          'Sterile Freeze-Dried Powder For Iv Infusion Or Injection': 1,
#          'Solution for Injection (IM/IV/SC)': 17,
#          'Solution S.C. for Injection': 1,
#          'Solution For Injection (IV/SC)': 39,
#          'Solution for Injection (S.C./I.V.)': 3,
#          'Solution For Sc Injection': 1,
#          'Powder For Concentrate For Infusion (Iv)': 1,
#          'Solution For Injection (Pre-Filled Syringe)': 1,
#          'Solution For Injection (Intravitreal)': 1,
#          'Solution for Injection/ 150mg/ml': 1,
#          'Powder for Concentrate for Solution for IV Infusion': 2,
#          'Suspension for Injection (SC) (Formulation: 30% Soluble Insulin and 70% Protamine Insulin Aspart Crystals)': 1,
#          'Lyophilized Powder for Concentrate Solution for IV Infusion': 3,
#          'Solution For Injection (Sc)': 29,
#          'Suspension For Injection (Im)': 5,
#          'Lyophilized Powder For Injection IV': 5,
#          'Suspension for Injection (IM/SC)': 12,
#          'lyophilized powder for solution for injection': 1,
#          'Powder For Solution For Intravenous Infusion': 1,
#          'Lyophilized Powder For Injection (SC)': 3,
#          'Solution For Injection (S.C.)': 11,
#          'Suspension for Injection (IM/IV/SC)': 1,
#          'Solution for Injection (I.V. / S.C.)': 2,
#          'Solution for Injection (IV / SC)': 12,
#          'Powder For Solution For Injection (SC)': 1,
#          'Suspension For Injection (IM)': 11,
#          'Powder for Solution for S.C. Injection': 1,
#          'Powder for Injection (IM)': 4,
#          'Concentrate For Solution For Infusion (IV)': 11,
#          'Solution for Injection (IV Infusion)': 28,
#          'Powder for Solution for Injection (SC)': 6,
#          'Suspension for Injection (SC) [1 mL of suspension contains 100 units soluble insulin aspart/protamine-crystallized insulin aspart in the ratio 50/50 (equivalent to 3.5 mg)]': 1,
#          'Solution For Injection (S.C./I.M.)': 1,
#          'Lyophilized Powder for Injection (IV/SC)': 4,
#          'Powder For Concentrate For Solution For Infusion': 2,
#          'Solution for IV Infusion': 146,
#          'Suspension for Injection (Deep Subcutaneous/I.M.)': 1,
#          'Suspension for Injection (SC)': 14,
#          'Solution for Injection (Intravitreal)': 2,
#          'Solution for Injection (S.C.)': 11,
#          'Concentrate for Solution for IV Infusion': 19,
#          'Hard Vaginal Capsule': 1,
#          'Powder for Solution for Intravenous Injection': 5,
#          'Powder For Solution For I.V. Infusion': 4,
#          'Solution for Injection (SC/IV)': 17,
#          'Orodispersible Tablet': 33,
#          'Solution For Injection/Infusion (SC/IV)': 1,
#          'Powder for Solution for Injection (IM)': 3,
#          'Solution for Injection (SC) (For Pediatric Use)': 1,
#          'Powder for Concentrate for solution for infusion': 1,
#          'Solution for I.V. Infusion': 46,
#          'Solution For Injection (IV)': 71,
#          'Powder for Concentrate for Solution for Infusion': 6,
#          'Lyophilized Powder for SC Injection + Diluent': 1,
#          'Suspension for Intramuscular Injection - Single Dose Syringe': 1,
#          'Solution for S.C. Injection': 1,
#          'Powder for Injection (IV)': 103,
#          'Solution For Injection (SC/IV)': 3,
#          'Powder For Solution For Injection (Im/Sc)': 2,
#          'Powder For Solution For Injection (IM)': 4,
#          'Sterile Suspension For Injection ( Sc )': 3,
#          'Powder for Solution for IV Infusion': 15,
#          'Solution for Infusion (IV)': 16,
#          'Solution for Injection (SC/IM)': 4,
#          'Solution For IV Infusion': 39,
#          'Solution For Injection (I.M./I.V./S.C.)': 8,
#          'Suspension For Injection (I.M./S.C.)': 1,
#          'Suspension For Injection (Im/Sc)': 6,
#          'Solution For Injection/ 5000 I.U.': 1,
#          'Lyophilized Powder for Injection (SC)': 4,
#          'Lyophilized Powder for Solution for Injection (IM/SC)': 3,
#          'Capsule': 3121,
#          'Solution for IM Injection': 4,
#          'Solution for Injection, Pre-Filled Pen (Mai)': 1,
#          'Solution for Injection in Pre-filled Autoinjector': 1,
#          'Pre-filled Syringe for Injection': 1,
#          'Solution For Injection': 246,
#          'Solution for Injection (Sc)': 2,
#          'Tablet': 4295,
#          'PRE FILLED SYRINGE': 2,
#          'Lyophilized Powder for Subcutaneous Injection': 1,
#          'Concentration For I.V. Solution': 1,
#          'Suspension For Injection (IM/SC)': 2,
#          'Powder And Solvent For Solution For Injection': 1,
#          'Suspension For Injection (S.C.)': 7,
#          'Freeze-Dried Injection In A Vial': 1,
#          'Freeze-dried Powder for Oral Suspension': 1,
#          'Suspension For Injection Im/Sc': 1,
#          'Solution For Intradermal Injection': 1,
#          'Concentrate for Solution for Infusion': 6,
#          'Concentrate For Solution For Infusion (Iv)': 4,
#          'Lyophilized Powder For Injection (S.C./I.M)': 1,
#          'Suspension For Im Injection': 3,
#          'Solution For Injection (Iv/Sc)': 14,
#          'Concentrate for Solution For Infusion (Iv)': 1,
#          'Solution for Injection (I.M./ S.C.)': 1,
#          'Powder for Concentrate Solution For Infusion (IV)': 1,
#          'Powder for Concentrate for Solution fro Infusion (IV)': 1,
#          'Solution For Injection (Sc/Iv)': 3,
#          'Powder and Solvent for Solution for Injection (SC)': 2,
#          'Solution for Injection in Pre-filled Pen': 1,
#          'Solution for Injection \n(SC)': 2,
#          'Solution For Injection SC': 5,
#          'Suspension For Injection IM': 1,
#          'Solution For Injection (I.M)': 4,
#          'Sublingual Tablet': 8,
#          'Lyophilized Powder for Solution \nfor Injection (IV)': 1,
#          'Lyophilized Powder for Solution for Injection (IV)': 1,
#          'Lyophilized Powder for Injection (ID)': 1,
#          'Suspension for Injection (SC) (30% Insulin Aspart and 70% Insulin Aspart Protamine)': 1,
#          'Cocentrate for Solution for IV Infusion': 2,
#          'Powder For Solution For Intratracheal Infusion': 1,
#          'Solution For Infusion IV': 1,
#          'Solution For Injection (IM)': 13,
#          'Suspension for Injection (SC) (30% \r\nSoluble Insulin and 70% Isophane Insulin)': 1,
#          'Concentrate For Solution For I.V. Injection': 2,
#          'Powder for Concentrate for Solution for Infusion (IV)': 2,
#          'Intratracheal Suspension': 1,
#          'Lyophilized Powder for Injection (IV)': 68,
#          'Oral Suspension': 90,
#          'Solution for Injection (IV/IM/SC)': 7,
#          'Solution for Injection (IM)': 21,
#          'Powder For Concentrate For Solution For Infusion (IV)': 3,
#          'Powder for Concentrate for Solution for \r\nInfusion (IV)': 1,
#          'Vascular Endothelial Growth Factor Inhibitors': 1,
#          'Concentrate For Solution Fo Infusion (IV)': 1,
#          'Powder for Injection (I.M./I.V.) (Monodose)': 1,
#          'Powder For Suspension': 372,
#          'Suspension for Injection (IM) (Monodose)': 1,
#          'Suspension for Injection (IM) (Pediatric-Single Dose)': 1,
#          'Suspension for Injection (I.M.)': 6,
#          'Lyophilized Powder for Injection (S.C.) Monodose (see formulation on reverse side)': 1,
#          'Lyophilized Powder for Injection (IM)': 6,
#          'Suspension for Injection (IM) (Preservative free)': 1,
#          'Suspension For Injection (I.M.)-Thiomersal Free': 1,
#          'Iv': 2,
#          'Freeze-Dried Powder For Suspension for Injection (S.C.)': 1,
#          'Suspension For Injection (I.M)': 3,
#          'Powder for Intravenous Injection or Infusion': 2,
#          'Solution for Injection (I.V.)': 23,
#          'Suspension For Injection(Im) Multidose': 1,
#          'Solution for IV Injection (IV Infusion)': 1,
#          'Solution for Injection (IV)': 123,
#          'Freeze-Dried Powder For Injection (Multidose) (SC)': 1,
#          'Suspension For Injection (IM) (Multidose)': 1,
#          'Freeze-Dried Powder For Injection (SC)': 1,
#          'Oral Suspension and Effervescent Granules': 1,
#          'Suspension for IM Injection': 3,
#          'Suspension for Injection (IM) (Preservative-free)': 1,
#          '2.5 IU/mL Lyophilized Powder for Injection (ID/IM)': 1,
#          'Lyophilized Powder For Injection': 59,
#          'Lyophilized Powder for Injection (IM/SC)': 4,
#          'Solution For Iv Infusion': 162,
#          'Suspension For Injection(IM)': 1,
#          'Suspension for Injection(IM) (Multidose) (Adult)': 1,
#          'Freeze-Dried Powder For Injection (I.D.)': 1,
#          'Suspension For Injection (IM) Single Dose (Adult)': 1,
#          'Solution For Injection (ID)': 1,
#          'Solution for Injection (IM.)': 2,
#          'Freeze-dried Powder for Injection (I.D.)': 1,
#          'Suspension for Injection (IM) (Pediatric)': 1,
#          'Solution for Injection (ID)': 1,
#          'Freeze-Dried Powder For Intradermal Injection': 1,
#          'Solution For Injection (I.M.)': 5,
#          'Suspension for Injection IM': 2,
#          'Solution For Oral Administration - Single Dose': 1,
#          'Suspension For Injection (I.M.)': 3,
#          'Suspension For IM Injection': 1,
#          'Freeze Dried Powder For Injection (I.M./I.D.)': 1,
#          '0.5 mL Suspension for Injection (IM) - 2PE (See reverse for Formulation)': 1,
#          'Solution For Infusion (Iv)': 8,
#          'Powder for Solution for Injection (S.C./I.M.)': 1,
#          'Lyophilized Powder For Injection (Id/Im)': 1,
#          'Suspension For Injection (Deep I.M.), 2PE Free': 1,
#          'Deep S.C./I.M. Single Use': 1,
#          'Enteric-Coated Capsule': 1,
#          'Freeze -Dried Powder for Injection (IM/ID)': 1,
#          'Solution for I.V. Injection': 10,
#          'Solution For Injection(Sc)': 1,
#          'Concentrate For Solution For I.V. Infusion': 4,
#          'Solution For IV Injection': 13,
#          'Power For Intravenous Infusion': 1,
#          'Solution For Injection (I.M./ S.C.)': 1,
#          'Solution for Infusion (IV/SC)': 1,
#          'Suspension for Injection (IM) - Single dose for Adolescent and Adult': 1,
#          'Concentrate For Solution For IV Injection': 1,
#          'Concentrate for Solution \r\nfor Infusion (IV)': 1,
#          'Lyophilized Poweder For Injection (IM/SC)': 1,
#          'Suspension For Injection (IM)-Thiomersal Free': 1,
#          'Suspension for Injection (IM) - Thiomersal Free': 1,
#          'Solution For Iv/Sc Injection': 1,
#          'Solution for Injection for IV Infusion': 4,
#          'Lyophilized Powder For Solution For Im Injection': 1,
#          'Solution for Injection (I.M./S.C.)': 4,
#          'Powder for Injection (SC)': 1,
#          'Im': 2,
#          'Powder and Solution For Injection (IM)': 1,
#          'Solution for Injection IM': 1,
#          'Lyophilized Powder For Injection (S.C.)': 1,
#          'Lyophilized powder for injection (SC)': 1,
#          'Lyophilized Powder For Intravesical Instillation': 1,
#          'Powder for Solution for Injection (IV Infusion)': 2,
#          'Solution For Injection (Sc/IV)': 1,
#          'Lyophilized Powder for Solution for Injection (S.C.)': 1,
#          'Solution For Injection (Iv Infusion)': 33,
#          'Suspension For Oral Use': 1,
#          'Lyophilized Powder for Intramuscular or Subcutaneous Injection': 1,
#          'Solution For Injection (S.C)': 1,
#          'Topical Solution (Spray)': 1,
#          'Ointment': 238,
#          'Lyophilized Powder For Injection ( S.C )': 1,
#          'Lyophilized Powder For Injection (Im/Sc)': 2,
#          'Concentrate For Solution For Iv Infusion/ 20Mg/Ml': 1,
#          'Solution For Injection (Iv)': 71,
#          'Suspension (Oral Drops)': 58,
#          'Solution For Infusion': 10,
#          'Freeze- Dried Powder For Injection ( S.C )': 1,
#          'Solution for Injection (IVT)': 1,
#          'Solution for Intravitreal Injection': 1,
#          'Lyophilized Powder For Intramuscular Or Subcutaneous Injection': 1,
#          'Freeze-dried Powder for Injection (SC)': 1,
#          'Lyophilized Powder for Solution for Injection (IM)': 2,
#          'Concentrate for Solution for Injection (IV Infusion)': 1,
#          'Suspension (Oral)': 1,
#          'Solution For Intravenous Infusion': 74,
#          'Solution For SC Injection': 1,
#          "Powder For Conc. For Sol'N For Iv Infusion": 2,
#          'Lyophilized Powder For Solution \r\nfor Injection (SC)': 1,
#          'Suspension For Injection (Sc)': 11,
#          'Freeze-Dried Powder for Solution for Injection \r\n(IM/SC)': 1,
#          'Freeze-Dried Powder for Solution for IM/SC Injection': 1,
#          'Lyophilized Powder For Injection (Sc)': 1,
#          'Lyophilized Powder for Solution for Injection': 2,
#          'Lyophilized Powder for Solution for Injection (IM / SC)': 1,
#          'Vial': 2,
#          'Lyophilized Solution for Injection': 1,
#          'Suspension for Injection (I.M)': 1,
#          'Solution For Injection (Im-Iv-Sc)': 1,
#          'Solution For Injection (Iv)/ 5000 Iu/Ml (25000 Iu/Ml)': 1,
#          'Solution For Injection (Iv)/ 1000 Iu/Ml (5000 Iu/5 Ml)': 1,
#          'Enoxaparin Sodium': 2,
#          'Powder For Injection (I.V.)': 81,
#          'Suspension for Injection': 1,
#          'Solution for Infusion (I.V.)': 13,
#          'Solution For Injection (Im/Sc)': 1,
#          'Solution for Infusion IV': 2,
#          'Solution For Infusion (I.V.)': 5,
#          'Lyophilized Powder For Injection (Iv)': 41,
#          'Suspension for Injection (SC)\r\n(30% Regular Insulin Human/70% Isophane Insulin Human)': 2,
#          'Suspension for Injection (SC) (30% Regular Insulin Human/70% Isophane Insulin Human)': 1,
#          'Powder For Oral Suspension': 126,
#          'Solution For Injection (Iv/SC)': 1,
#          'Solution For Injection (I.V/S.C)': 2,
#          'Powder For Solution For Injection (Sc)': 1,
#          'Lyophilized Powder For Solution For Injection (Im/Id)': 1,
#          'Powder for Injection (IM/SC)': 1,
#          'Solution For Injection (Equine)': 1,
#          'Solution For Injection (Iv / Sc)': 2,
#          'Solution for Injection IV / SC': 1,
#          'Solution For Injection(IV/SC)': 1,
#          'Solution For Injection(Iv/Sc)': 1,
#          'Solution for Infusion': 9,
#          'Solution For Injection SC / IV': 1,
#          'Solution For Injection (I.V.)': 28,
#          'Solution For Injection I.M': 1,
#          'Solultion For Injection (IV/SC)': 1,
#          'Powder for Solution for Injection (IM/SC)': 1,
#          'Powder for Suspension (Oral Drops)': 18,
#          'Concentrate for Solution for Infusion \r\n(IV)': 3,
#          'Concentrate For Solution For Injection': 1,
#          'Concentrate for Solution For Infusion (IV)': 1,
#          'Solution for Injection \r\n(IV/SC)': 18,
#          'Solution for Injection \r\n(IV)': 4,
#          'Concentrate for Solution \r\nfor Injection (IV Infusion)': 1,
#          'Solution for injection (IV/SC)': 3,
#          'Solution for \r\nInjection (IV/SC': 1,
#          'Solution for Injection (IM/IV)': 192,
#          'Solution For Injection (I.V., S.C.)': 2,
#          'Solution for \r\nInjection (SC': 3,
#          'Solution for \r\nInjection (SC/IV)': 1,
#          'Film-Coated Tablets': 15,
#          'Film-Coated Tablet': 4537,
#          'Film-coated Tablet': 98,
#          'Concentrate for Solution for \r\nInfusion (IV)': 2,
#          'Film Coated Tablet': 636,
#          'Sugar Coated Tablet': 8,
#          'Film Coated Tablets': 7,
#          'Film-Coated Tab': 1,
#          'Solution for Injection (IV/IM)': 16,
#          'Solution for Injection (I.V./I.M.)': 13,
#          'Film-coated tablet': 28,
#          'Solution for Injection (I.M./I.V.)': 54,
#          'Solution for Injection \r\n(I.M./I.V.)': 7,
#          'Solution For Injection (I.V./I.M.)': 7,
#          'Film- Coated Tablet': 29,
#          'Solution for Injection (I.V./I.M.': 1,
#          'Solution For Injection (Im/Iv)': 142,
#          'Solution For Injection (I.M./I.V.)': 63,
#          'Solution for Injection \r\n(I.V./I.M./Intrasynovial)': 1,
#          'Film- coated tablet': 1,
#          'Lyophilized Powder for Injection (I.V.)': 25,
#          'Lyophilized Powder for Solution for Infusion (I.V.)': 1,
#          'Lyophilized Powder for Solution for Infusion (IV)': 1,
#          'Lyophilized Powder for Injection for I.V. Infusion': 7,
#          'Lyophilized Powder for Injection for I.V. \r\nInfusion': 4,
#          'Lyophilized Powder for Solution for Infusion \r\n(I.V.)': 1,
#          'Lyophilized Powder For solution for Infusion (IV)': 1,
#          'Powder For Injection (I.M./I.V.)': 115,
#          'Syrup': 1447,
#          'Cream': 373,
#          'Sterile Suspension (Opthalmic Drops)': 1,
#          'Solution For Injection (IV/IM)': 9,
#          'Otic Solution': 27,
#          'Suspension': 385,
#          'Pump Spray': 1,
#          'Topical Cream': 116,
#          'Elixir (Pediatric/Geriatric)': 1,
#          'Extended Release Tablet': 62,
#          'Powder For Injection (Im/Iv)': 246,
#          'Lotion': 32,
#          'Vaginal Suppository': 21,
#          'Sterile Powder For Injection (I.M./I.V.)': 2,
#          'Solution for Injection (I.M.)': 9,
#          'Powder for Injection ( IM / IV': 3,
#          'Solution For Injection (Im/ Iv)': 8,
#          'Powder for Suspension': 122,
#          'Solution For Iv Injection': 14,
#          'Topical Ointment': 24,
#          'Solution For Injection (IM/IV)': 96,
#          'Solution for IV infusion': 6,
#          '1,500 I.U. 100 I.U. 8.330 mg 4.160 mg 1.670 mg 8.330 mcg 8.330 mcg 1.66 mg 83.330 mg': 1,
#          'Sugar-Coated Tablet': 24,
#          'Liquid': 14,
#          'Jelly': 1,
#          'OINTMENT': 10,
#          'Pediatric Syrup': 4,
#          'Rectal Suppository': 24,
#          'Topical Solution': 164,
#          'Powder For Suspension (Oral Drops)': 63,
#          'Solution For Scalp Application': 2,
#          'Sterile  Solution For Injection (IM/IV/SC)': 1,
#          'Solution For Injection (I.M. / I.V.)': 2,
#          'Syrup (Oral Drops)': 289,
#          'Liquid Enema': 2,
#          'Sustained Release Tablet': 25,
#          'Chewable Tablet': 282,
#          'Granules for Suspension': 54,
#          'vial': 1,
#          'Softgel Capsule': 252,
#          'Ear Drops': 7,
#          'capsule': 20,
#          'Powder for Oral Suspension': 58,
#          'Sterile Ophthalmic Solution': 52,
#          'Sterile Eye Drops': 5,
#          'Sterile Powder for Injection (I.M./ I.V.)': 1,
#          'Powder For Suspension (Strawberry Flavor)': 2,
#          'Powder for Injection': 87,
#          'Elixir/Syrup': 1,
#          'Metered Dose Inhaler': 52,
#          'Solution For  Injection IV': 1,
#          'Syrup (Oral drops)': 11,
#          'Solution for Injection (Epidural, Intrathecal, \r\nPeripheral, Local Infiltration and Peribulbar Block)': 1,
#          'Solution for Subcutaneous Injection': 1,
#          'Sterile Ophthalmic Suspension': 15,
#          'Topical Gel': 47,
#          'Controlled-Release Tablet': 19,
#          'Concentrate for Solution for Intravenous InfusionSolution for Injection': 1,
#          'Sterile Ophthalmic Solution (Eye Drops)': 25,
#          'Suppository': 12,
#          'Elixir': 7,
#          'Emollient Cream': 1,
#          'Powder For Injection (Iv)': 104,
#          'Powder for Suspension (Drops)': 1,
#          'Solution for Injection (Epidural, Local Infiltration)': 1,
#          'Syrup (Drops)': 3,
#          'Solution For I.V. Infusion': 69,
#          'Powder For Iv Infusion': 2,
#          'Ophthalmic/Otic Suspension (Drops)': 1,
#          'Otic Suspension (Drops)': 1,
#          'Tablet, sustained release': 1,
#          'Tablet, long acting': 1,
#          'Modified-Release Tablet': 65,
#          'Modified Release Tablet': 40,
#          'Solution for infusion (IV)': 1,
#          'Solution for Iv Infusion': 3,
#          'Ophthalmic Suspension': 19,
#          'Solution for I.V Infusion': 4,
#          'Solution for Inhalation': 23,
#          'Syrup (Strawberry Flavor)': 19,
#          'Sterile Ophthalmic Solution (Drops)': 12,
#          'Buffered Solutions (Nasal Drops)': 1,
#          'Oral Solution': 87,
#          'Ophthalmic Solution': 102,
#          'Not Applicable': 2,
#          'Powder for Inhalation': 8,
#          'Nebulizing Suspension (Sterile)': 4,
#          'Dialysis Solution': 8,
#          'Strerile Water for Injection': 1,
#          'Ophthalmic Ointment': 18,
#          'cream': 5,
#          'Oral Gel': 3,
#          'Medicated Oil': 2,
#          'Ophthalmic Solution (Eye Drops)': 71,
#          'Ophthalmic Suspension (Drops)': 3,
#          'Granules For Suspension': 121,
#          'Solution For Iv Solution': 2,
#          'Powder For Injection': 246,
#          'Solution': 255,
#          'Susupension': 1,
#          'Powder for Injection (IM/SC) [Sustained Release]': 1,
#          'Solution for Injection (IV or Intravesical)': 1,
#          'Granules For Oral Suspension': 31,
#          'Sterile Ophthalmic Ointment': 6,
#          'Suspension For Injection (Im/ Intra-Articular/  IntraBursal/ Periarticular/ Intralesional)': 1,
#          'Solution for Injection (IM / IV)': 12,
#          'Solution for Injection (1.M./I.V.)': 2,
#          'Solution (amber bottle x 30mL)': 1,
#          'SOLUTION (Nail Lacquer)': 1,
#          'Suspension For Intratracheal Administration': 1,
#          'Lyophilized Powder For Injection (I.V.)': 40,
#          'Aqueous Nasal Spray': 3,
#          'GRANULES FOR SUSPENSION': 1,
#          'Powder for Intravenous (IV) Infusion': 2,
#          'Powder For Injection (IM/IV)': 205,
#          'Powder for Injection (I.M./I.V.)': 91,
#          'Liquid Oil (Sweet Orange Flavor)': 1,
#          'Gel': 40,
#          'Solution (Oral Drops)': 6,
#          'Granules for Oral Suspension': 13,
#          'Sterile Powder For Infusion': 2,
#          'Intraocular Irrigating Solution': 2,
#          'Emulsion for IV Infusion': 9,
#          'Suspension (Orange Flavor)': 15,
#          'Nebulizing Solution': 3,
#          'Depot In Pre-Filled Syringe (Sc Injection)': 1,
#          'Syrup (Oral Drops) Orange Flavor': 6,
#          'Solution for Nebulizing': 1,
#          'Extended-Release Tablet': 115,
#          'Granules For Suspension (Drops)': 1,
#          'Powder For Susp.(Oral Drops)': 1,
#          'SYRUP': 14,
#          'Solution for Intravenous Injection': 10,
#          'Solution for IV Injection': 11,
#          'Solution for Injection (SC/IM/IV)': 3,
#          'IV Solution': 3,
#          'Oral Tablet': 3,
#          'Suspension (See reverse for formulation)': 1,
#          'SUSPENSION': 4,
#          'Ophthalmic Solution (Drops)': 28,
#          'Sterile Concentrate Solution for I.V. Infusion': 1,
#          'Herbal Tea': 2,
#          'Granules for Suspension (Oral Drops)': 6,
#          'Parenteral Solution For I.V. Infusion': 1,
#          'Opthalmic Solution (Drops)': 4,
#          'Solution, oral': 4,
#          'Retard Tablet': 3,
#          'Powder for Aqueous Injection': 1,
#          'Powder For Suspension (Drops)': 1,
#          'LOTION': 3,
#          'Granule For Suspension (Oral Drops)': 1,
#          'Solution for Injection (I.M. /I.V.)': 3,
#          'Solution for I.V. Injection (IV)': 1,
#          'Trandermal Patch': 1,
#          'Sterile Powder for Injection (I.M/I.V)': 1,
#          'Parenteral Solution': 3,
#          'Solution For Injection (IV Infusion)': 13,
#          'CAPSULE': 32,
#          'Sterile Powder for Injection (I.M)': 1,
#          'Scalp Lotion': 3,
#          'Solution For Injection (I.M./S.C./I.V.)': 1,
#          'Oral Suspension (Choco Flavor)': 1,
#          'Powder for Injection (IM/IV/SC)': 1,
#          'Dental Paste': 1,
#          'Powder For Injection (Im/Sc) \r\nSustained Release': 1,
#          'Powder for Injection (IM/IV)': 326,
#          'Nasal Spray': 18,
#          'Dispersible/Chewable Tablet': 2,
#          'Granules For Suspension (Pineapple Flavor)': 1,
#          'Powder for injection (IM / IV)': 1,
#          'Softgel capsule': 11,
#          'Rectal Suspension for Enema': 1,
#          'See attached': 1,
#          'Granules for Oral Solution': 8,
#          'Enteric-Coated Tablet': 181,
#          'Powder for Suspension (Oral drops)': 1,
#          'Sterile Ophthalmic Gel': 1,
#          'Soft-Gelatin Capsule': 8,
#          'Powder for suspension (Oral Drops)': 1,
#          'Powder For Oral Solution': 78,
#          'Sustained-Release Tablet': 64,
#          'Ophthalmic Gel': 5,
#          'Powder For Oral Suspension (Oral Drops)': 3,
#          'Powder For Suspension (Oral Drops )': 1,
#          'Solution for Intravascular Injection': 1,
#          'Oral Drops': 16,
#          'Solution For Peritoneal Dialysis': 2,
#          'Solution for Intraperitoneal Administration': 5,
#          'tablet': 16,
#          'Solution for Injection IM / IV': 1,
#          'Granules for Solution': 6,
#          'Oral Capsule': 2,
#          'Disinfectant Solution': 1,
#          'Solution For Injection (Iv/Im)/ 100 Mg/Ml (500 Mg/5Ml)': 1,
#          'Dry Powder For Inhalation': 7,
#          'Effervescent Tablet': 38,
#          'Granules For Solution': 11,
#          'Prolonged-Release Tablet': 34,
#          'Solution For Intravascular Injection': 2,
#          'Lyophilized Powder For Intravenpus Injection': 1,
#          'Sterile Ophthalmic solution': 1,
#          'Lyophilized Powder For Intravenous Injection (IV)': 1,
#          'Granules For Suspension (Oral Drops)': 35,
#          'Metered-Dose Inhaler (Non-Cfc)': 2,
#          'Inhaler': 6,
#          'Intravenous Infusion': 4,
#          'fluid for injection': 1,
#          'Solution For Spinal Injection': 6,
#          'Powder For Injection (I.M./M.R)': 1,
#          'Lyophilized Powder for Injcetion (IM/SC) Sustained Release': 1,
#          'Suspension For Inhalation (Nebules)': 1,
#          'None': 45,
#          'Solution For Injection/ Infusion (I.M./I.V./S.C./I.A.)': 1,
#          'Powder For Injection (Im. Iv, Ia, Intraperitoneal, Intrapleural)': 2,
#          'Shampoo': 17,
#          'Sustained-Release tablet': 1,
#          'Concentrate For I.V. Infusion': 1,
#          'Film - Coated Tablet': 38,
#          'Intrauterine Delivery System': 1,
#          'Ophthalmic suspension': 1,
#          'Powder for Injection (I.V.)': 36,
#          'Ophthalmic solution': 5,
#          'Solution For Injection (I.V./I.A./Intravesicular)': 2,
#          'Concentrate For Infusion (I.V.)': 1,
#          'Concentrate For Iv Infusion': 1,
#          'TOPICAL SOLUTION': 2,
#          'Solution For Inhalation': 41,
#          'Solution For Injection (Intravenous/Intra-arterial/Intrathecal/Body Caveties)': 1,
#          'Concentrate For Infusion': 1,
#          'Solution For Injection (I.M/I.V)': 3,
#          'Metered Dose Inhaler (CFC-Free)': 1,
#          'Solution for Injection (IM/IV/Intrathecal/Intra-arterial)': 1,
#          'Solution For Injection IV': 2,
#          'Liquid For Inhalation': 4,
#          'Depot Solution For Subcutaneous Injection': 1,
#          'Emulsion for Intravenous Infusion': 4,
#          'Solution For Injection (I.M./ I.V.)': 1,
#          'Lyophilized Powder for I.V.Injection': 1,
#          'Suspennsion': 1,
#          'Powder for Injection (I.V./ Intraperitoneal/ Intrapleural/ I.A.)': 1,
#          'Solution with 1.5% Dextrose (For \r\nIntraperitoneal Administration)': 1,
#          'Solution for Intraperitoneal Administration \r\n(Dialysis)': 1,
#          'Solution With 2.5% Dextrose': 1,
#          'Powder For Injection (I.M.)': 1,
#          'Sterile Irrigating Solution': 1,
#          'Powder For Suspension For Injection': 1,
#          'FIlm-Coated Tablet': 1,
#          'Filmcap': 1,
#          'Lyophilized Powder for Injection': 13,
#          'Syrup (Oral Drops) Strawberry Flavor': 1,
#          'Vaginal Gel': 4,
#          'Vaginal Insert': 2,
#          'Ophthalmic Drops': 8,
#          'Suspension / Syrup': 1,
#          'Transdermal Patch': 23,
#          'Solution for injection (IM/IV)': 4,
#          'Enteric-Coated Pellets in Capsule': 1,
#          'Powder for IV Infusion': 5,
#          'Sterile Solution for Nebulization': 1,
#          'Powder For Inhalation': 6,
#          'Sterile Powder for Injection': 2,
#          'Capsules': 18,
#          'Forte Syrup': 1,
#          'Iv Solution': 2,
#          'Dispersible Tablet': 36,
#          'Powder For Injection (Iv/Im)': 11,
#          'Otic Suspension': 2,
#          'Solution (Ophthalmic Drops)': 1,
#          'Suspension (Strawberry Flavor)': 11,
#          'Suspension (Melon Flavor)': 7,
#          'ER Tablet': 1,
#          'Film Tablet': 1,
#          'Sustained-Release Film-Coated Tablet': 1,
#          'Emulgel': 1,
#          'Film -Coated Tablet': 4,
#          'Suspension/Syrup': 2,
#          'Solution For Injection (Iv/Im/Sc)': 2,
#          'Lyophilized Powder for IM/IV Injection': 1,
#          'Solution For Injection (Im)': 6,
#          'Soft Gel Capsule': 13,
#          'Sterile Otic Suspension (Ear Drops)': 1,
#          'Sterile Ophthalmic Suspension(Eye Drops)': 1,
#          'Pediatric Suppository': 1,
#          'Sterile Ophthalmic Suspension (Drops)': 2,
#          'Sterile Otic Suspension': 1,
#          'Solution For Nebulization': 11,
#          'Solution for Injection \r\n(I.M.A.V.)': 1,
#          'Sterile Ophthalmic Suspension Eye Drops': 1,
#          'Enteric Coated Tablet': 40,
#          'Concentrate For Iv Infusion Or Oral Solution': 1,
#          'Respiratory Suspension': 1,
#          'ophthalmic ointment': 1,
#          'Emulsion For Intravenous Injection': 1,
#          'Soft-gelatin capsule': 1,
#          'Antiviral': 1,
#          'Prolonged-Release Powder For Injection (Im)': 2,
#          'Prolonged-Release Powder For Suspension For Injection (Im)': 1,
#          'Sterile Ophthamic Solution': 1,
#          'Sustained-Release Capsule': 30,
#          'Film - Coated  Tablet': 1,
#          'Powder For Injection (I.V./I.V. Infusion)': 2,
#          'Sodium for injection IV / IM': 1,
#          'Gastro-Resistant Tablets (Film-Coated)': 1,
#          'Delayed Released Tablet': 2,
#          'Spray Solution': 2,
#          'Saline Solution': 1,
#          'Powder For Solution': 10,
#          'Solution For Nasal Spray': 2,
#          'Nebulizing Solution For Inhalation': 1,
#          'Emulsion For Intravenous Infusion': 3,
#          'Powder For Injection (I.V/I.M.)': 3,
#          'SOLUTION FOR INJECTION': 3,
#          'Suspension for nebulization': 1,
#          'Sterile Opthalmic Gel': 1,
#          'Solution For Injection (IM/IV/SC)': 13,
#          'Powder For Injection/Infusion (Iv)': 1,
#          'Fast Disintegrating Tablet': 2,
#          'Powder For Injection (I.M/I.V.)': 10,
#          '2 GRAM TEA BAG': 1,
#          'Solution for Injection (For Intravenous Infusion Only)': 1,
#          'Lyopjilized Powder for Injection (IV)': 2,
#          'Lyopjilized Powder For Injection (Iv)': 1,
#          'Lyophilized  Powder for Injection (IV)': 2,
#          'Concentrate For Solustion For I.V. Infusion': 1,
#          'Solution For Injection (I.M/I.V.)': 3,
#          'Metered-Dose Inhaler': 7,
#          'Suspension;Suspension;Syrup': 1,
#          'Solution For Nebulization (Pulmoneb)': 1,
#          'Syrup (Cherry Flavor)': 13,
#          'Sprinkle Capsule': 1,
#          'Powder for Oral Solution': 29,
#          'Ophthalmic Emulsion': 1,
#          'Suspension For Injection(Im)': 1,
#          'Powder For Injection (IV)': 71,
#          'Sterile Solution For Iv Infusion': 2,
#          'Sterile Suspension (Ophthalmic Drops)': 1,
#          'Solution for IV Infusion (Pediatric \r\nSolution)': 1,
#          'Concentrate Solution For Iv Infusion': 11,
#          'Opththalmic Solution': 1,
#          'Vial Powder For Injection': 1,
#          'SOLUTION FOR IV INFUSION': 1,
#          'Syrup (Orange Flavor)': 44,
#          'Kit Contains Suspension + Syrup': 2,
#          'otic drops': 1,
#          'Solution for Inhalation (Metered Dose Inhaler)': 1,
#          'Syrup (Oral Drops) - Grape Flavor': 1,
#          'Forte Suspension': 1,
#          'Dusting Powder': 2,
#          'Lyophilized Powder for Injection (IV Infusion)': 13,
#          'ophthalmic solution': 1,
#          'Solution for Irrigation': 2,
#          'Lyophilized Powder For Intravenous Injection And Infusion': 1,
#          'Powder For Injection (I.V./I.M.)': 8,
#          'Syrup (Grape Flavor)': 8,
#          'Vaginal Tablet': 16,
#          'Film-Coated Tablet( contains Sustained- Release Verapamil layer and \r\nImmediate-Release Trandolapril layer )': 1,
#          'Liquid for Inhalation': 4,
#          'Emulsion for Infusion (IV)': 1,
#          'Powder for Solution for Intratracheal Infusion': 1,
#          'Lyophilized Sterile Powder For Injection (Iv)': 2,
#          'Intavenous injection': 2,
#          'Concentrate Solution for IV Infusion': 50,
#          'Concentrate For Intravenous Infusion': 1,
#          'Concentrate Solution': 1,
#          'Sterile Ophthalmic Solution(Drops)': 1,
#          'Sterile Powder for Injection (IM/IV)': 4,
#          'Sustained Release Capsule': 16,
#          'Solution for IV Infusion ()': 1,
#          'Film-Coated tablet': 10,
#          'Lyophilized Powder Injection (IV)': 1,
#          'Otic Solution (Drops)': 3,
#          'Suppository (Rectal)': 1,
#          'Powder For Injection (Iv Infusion)': 3,
#          'Water for Injection': 2,
#          'Concentrate for Solution for Injection (IV)': 3,
#          'Suspension for Injection (1.M.)': 1,
#          'Solution for Injection (IM/IV/IA)': 2,
#          'Prolonged Release Film-Coated Tablet': 1,
#          'Solution for Injection/Infusion': 1,
#          'Syrup (COLA Flavor)': 1,
#          'Powder for Injection (I.V./I.M.)': 12,
#          'Lozenge': 50,
#          'Lyophilized Powder For Iv Infusion': 14,
#          'Delayed Release Tablet': 10,
#          'Transdermal patch': 4,
#          'Flim-Coated Tablet': 2,
#          'Soln For Inj (Im/Iv)': 1,
#          'Powder For Suspension Oral Drops': 1,
#          'Solution For Injection In Pre-Filled Syringe': 1,
#          'Fim-Coated Tablet': 7,
#          'Astringent Solution': 1,
#          'Solution For Injection (Iv/Ia)': 2,
#          'Adult Solution (Oral Drops)': 4,
#          'Solution For Injection/ 125 Mg/Ml (500 Mg/4 Ml)': 1,
#          'Delayed-Release Capsule': 63,
#          'Sterile Ophthalmic Solution [Benzalkonium chloride (BAK) Free Formula]': 1,
#          'Sterile Opthalmic Solution': 2,
#          'Oil-In-Water Emulsion For Injection (Iv Infusion)': 1,
#          'O/W Emulsion for Injection (IV/IV Infusion)': 1,
#          'Opthalmic Solution': 18,
#          'Sterile Solution For Injection Im/Iv': 1,
#          'Emulsion For Iv Infusion': 4,
#          'Dry Powder for Inhalation in Capsule': 10,
#          'Sterile Opthalmic Solution (Eye Drops)': 1,
#          'Lyophilized Powder': 2,
#          'Solution For Injection Im/Iv': 2,
#          'Solution For Injection (Ia/Iv)': 2,
#          'Sterile Suspension for IM Injection': 1,
#          'Powder for Injection (M/IV)': 1,
#          'Steril Solution For Injection': 1,
#          'Sterile Solution For Injection': 2,
#          'Pediatric Granules': 1,
#          'Sterile Solution Ophthalmic Dye': 1,
#          'Powder for Injection (I.M./ I.V.)': 4,
#          'Sachet Oral Powder': 1,
#          'Emteric Coated Tablet': 1,
#          'Powder for injection (IV Infusion)': 1,
#          'Tablet, extended release': 3,
#          'Soln. For Infusion (I.V.)': 1,
#          'I.V. Solution': 1,
#          'Volatile Liquid for Inhalation': 3,
#          'Solution for IV Infusion (Isotonic with 0.9% Sodium Chloride)': 1,
#          'Granules': 2,
#          'Solution for Intravenous Injection (I.V.)': 1,
#          'CREAM': 8,
#          'Metered Dose Inhaler (Cfc Free)': 3,
#          'Powder For Injetion (Im/Iv)': 1,
#          'Sterile Ophthalmic Solution (eye drops)': 1,
#          'Lipid Complex Suspension for Injection (IV)': 1,
#          'DELAYED-RELEASE CAPSULE': 2,
#          'Suspension For Nasal Spray': 3,
#          'Powder for I.M/I.V.': 2,
#          'Solution for Intravenous Infusion (IV)': 1,
#          'Normal Saline Solution': 1,
#          'Sterile Water for Injection (Solution)': 1,
#          'Lyophilized Powder For I.V. Infusion': 3,
#          'Granules For Suspesion (Drops)': 1,
#          'Oral Lyophilisate': 1,
#          'Film coated Tablet': 10,
#          'ointment': 1,
#          'Sterile Opthalmic Suspension': 3,
#          'concentrated solution for iv infusion': 2,
#          'Sterile Powder For Injection': 4,
#          'Gastro-Resistant Granules For Oral Suspension': 1,
#          'Throat Spray': 2,
#          'Granules for Suspension (Orange Flavor)': 2,
#          'Granules For Oral Injection': 1,
#          'Powder For Injection (I.M./I.V)': 6,
#          'Powder for Oral Drops': 1,
#          'Lyophilized Powder For Injection (I.V. Infusion)': 6,
#          'Lyophilized Powder For Injection (I.V. )': 1,
#          'Metered Dose Nasal Spray': 2,
#          'Concentrate Solution for Injection (IV)': 2,
#          'Powder For Injection (I.V)': 21,
#          'Lyophilized Powder for IV Infusion': 17,
#          'Powder For Intravenous Injection': 1,
#          'Syrup;Suspension;Suspension': 1,
#          'Solution For I.V Infusion': 5,
#          'Tablets': 7,
#          'Softgel Capsules': 8,
#          'Solution for Injection or \r\nConcentrate for Solution for Infusion (I.M./I.V.)': 2,
#          'Sterile Ophthalmic Drops': 2,
#          'Controlled Release Capsule': 6,
#          'Powder for Injection (IM / IV)': 12,
#          'Powder for Injection IM': 1,
#          'Film coated tablet': 17,
#          'Solution for SC/IV Injection/Infusion': 1,
#          'Eye Drops Solution': 6,
#          'Concentrate For Solution For IV Infusion': 2,
#          'Oral Rinse Solution': 1,
#          'Lyophilized Powder for IV  Injection': 1,
#          'Ophthalmic Suspension (Eye Drops)': 5,
#          'film coated tablet': 4,
#          'Opththalmic Suspensio (eye Drops)': 1,
#          'Effervescent Granules': 8,
#          'Pfi (I.M. / I.V.)': 2,
#          'Lyophilized Powder For Injection (I.M./I.V.)': 3,
#          'Sterile Otic Solution(Ear Drops)': 1,
#          'Nasal Solution (Spray)': 2,
#          'Concentrate Solution for I.V. Infusion': 21,
#          'Sterile Ophthalmic Suspension (Eye Drops)': 3,
#          'See Formulation On Reverse Side': 1,
#          'Modified- Release Tablet': 2,
#          'Sterile Powder For Injection (IV)': 1,
#          'Sterile Powder For Injection (I.V.)': 1,
#          'Prolonged Release Capsule': 9,
#          'Solution For I.V. Injection': 3,
#          'Sodium Chloride Solution for Intravenous Infusion': 1,
#          'Fine Granules': 1,
#          'Hard Capsule': 1,
#          'Sol for Injection (IV/IV Infusion)': 1,
#          'Powder for Injection (I.M.)': 2,
#          'TABLET': 18,
#          'Solution For Injection I.M./I.V.)': 2,
#          'Powder for injection (I.M./I.V.)': 1,
#          'Dry Powder Inhalation In Capsule': 3,
#          'Oral Powder For Suspension': 1,
#          'Solution for injection ( IV Infusion)': 2,
#          'Modified-Release Capsule': 12,
#          'Solution for Im Injection': 1,
#          'Concentrate Solution For IV Infusion': 4,
#          'Transderma Patch': 1,
#          'Lyophilized Powder For Injection (IV Infusion)': 9,
#          'Powder for oral Suspension': 1,
#          'SUPPOSITORY': 1,
#          'Controlled Release Tablet': 7,
#          'Solution For Injection For I.V. Infusion': 1,
#          'Powder for Oral Inhalation': 1,
#          'Microsphere Gel': 2,
#          'Powder for I.V. Infusion': 1,
#          'Antibacterial (Fluoroquinolone)': 1,
#          'Powder for Intravenous Injection (I.V.)': 1,
#          'Opthalmic Solution ( Drops )': 1,
#          'Concentrate Solution For Infusion': 2,
#          'Powder For Injection  (IM)': 1,
#          'Effervescent Granules For Solution': 1,
#          'Sustained- Release Tablet': 5,
#          'Solution For Intravenous Injection': 11,
#          'Powder For Iv Injection': 21,
#          'Solutiuon For Intravenous Infusion': 1,
#          'Nasal Spray Solution': 1,
#          'Emulsion for Injection (I.V.)': 3,
#          'Solution for Intravenous \r\nInfusion': 7,
#          'Lyophilized Powder for IV Injection': 11,
#          'Lyophilized Powder for I.V. Infusion': 4,
#          'Sterile Water for Injection (IM/IV)': 1,
#          'Powder For Injection + Solution For Injection': 2,
#          'Solution Spray': 1,
#          'Controlled-Release Capsule': 1,
#          'Lyophilized Powder for Injection (I.M./I.V.)': 2,
#          'Prolonged Release Suspension For Injection (IM)': 3,
#          'Solution for Injection (I.V)': 6,
#          'Fat Emulsion for Infusion (I.V.)': 1,
#          'Fat Emulsion For Iv Infusion': 1,
#          'Powder For Injection (IV/SC)': 1,
#          'Enteric Coated Capsule': 1,
#          'Powder for Oral Injection': 1,
#          'Capsule (see reverse for formulation)': 1,
#          'Softgel Caspule': 2,
#          'Solutionn for IV Infusion': 1,
#          'Lyophilized Powder For Injection (Iv Infusion)': 4,
#          'Caplet': 5,
#          'OTIC SOLUTION': 1,
#          'Soft Gelatin Capsule': 15,
#          'Orally Distintegrating Tablet': 1,
#          'Solution for Injection / Infusion': 1,
#          'Concentrate Solution (IV)': 1,
#          'Concentrate Solution for \r\nIV Infusion': 1,
#          'Solution for Injection (Local Infiltration)': 3,
#          'Buffered Solution Nasal Drops': 2,
#          'Solution for injection (IV/IM/SC)': 1,
#          'Nasal Solution (Drops)': 5,
#          'Lyophilized Powder For I.V Infusion': 4,
#          'Lyophilized Powder For IV Infusion': 4,
#          'Solution For injection (Im/Iv)': 2,
#          'Medicated Plaster': 5,
#          'Monitored-Release Tablet': 2,
#          'Soft Gelatin Capsule For Vaginal Use': 1,
#          'Modified-Release Vaginal Suppository': 1,
#          'Solution  for Injection (IV)': 1,
#          'Powder Fo Suspension (Oral Drops)': 2,
#          'Powder For Injection (IM)': 2,
#          'Film Coated tablet': 14,
#          'POWDER FOR INJECTION (IM/IV)': 2,
#          'Chewable tablet': 2,
#          'Sustained-release Tablet': 1,
#          'Emulsion For IV Infusion': 1,
#          'POWDER FOR INJECTION': 15,
#          'Oral Disintegrating Tablet': 3,
#          'Concentrate for Solution for Injection (I. V.)': 1,
#          'Lyophilized Powder For Injection  Iv Infusion': 1,
#          'FILM COATED TABLET': 5,
#          'Concentrate For Solution For Iv Infusion': 7,
#          'Solution For Irrigation': 5,
#          'Eye Drops': 3,
#          'Soln For Inhalation': 1,
#          'Granules for suspension': 2,
#          'Metered Dose Inhaler (Cfc-Free)': 1,
#          'Sterile Suspension (Intratracheal/Intrabronchial)': 1,
#          'ENTERIC-COATED TABLET': 3,
#          'Freeze-Dried Powder for Injection': 2,
#          'Subdermal Implant': 1,
#          'Powder For oral Suspension (oral Drops)': 1,
#          'Delayed Release Capsule': 27,
#          'Powder For Injection  Iv': 1,
#          'Concentrate Solution For I.V. Infusion': 5,
#          'Granules For Oral Solution': 6,
#          'Powder For I.V. Injection': 2,
#          'Powder for I.V. Injection': 1,
#          'Powder For Injection (Im/ Iv)': 3,
#          'Delayed-Release Tablet :': 1,
#          'Powder For injection (Iv)': 1,
#          'Solution For Peripheral Venous Infusion': 1,
#          'Solution For Injecion (I.V)': 1,
#          'Solution For (Iv) Injection': 3,
#          'Buffered Solution Nasal Spray': 1,
#          'Opthalmic Solution Drops': 2,
#          'Solution For Injection (I.M./S.C.)': 2,
#          'Dry powder for Inhalation': 1,
#          'Concentrate Sterile Solution For Iv Infusion': 1,
#          'Lyophilized Powder for Injection I.V. Infusion': 2,
#          'Solution for Injection (I.V Infusion)': 1,
#          'Solution For Injection (IM/IV/SC': 2,
#          'Powder For injection (Im/Iv)': 2,
#          'Lyophilized Powder For Injection (IV)': 34,
#          'Dry Powder For Inhalation Capsule': 2,
#          'Volatile Liquid For Inhalation': 6,
#          'Emulsion For Iv Injection': 1,
#          'Solution For Nanoparticle Injection For Infusion (IV)': 1,
#          'Lyophilized Powder For Injection (Iv Infusion': 1,
#          'Nasal Sray': 1,
#          'Fim-coated Tablet': 2,
#          'Soft Gelatin Capsule (For Vaginbal Use)': 1,
#          'Disperable Tablet': 1,
#          'Opthalmic Suspension': 1,
#          'Dry Powder For Inhalation In Capsule': 7,
#          'Powder For Injection  (Im/Iv)': 2,
#          'Solution For Injection (IM/SC/IV)': 2,
#          'Vaginal Soft Gelatin Capsule': 1,
#          'Solution For Injection for IV Infusion': 1,
#          'Lyophilized Powder for Injection (IM/IV)': 16,
#          'Lyophilized Powder For Iv Injection/Infusion': 3,
#          'Solution For Injection (I.V. Infusion)': 5,
#          'Powder for Concentrate for Solution for Injection (Intravenous Infusion)': 1,
#          'DispersIble Tablet': 2,
#          'Lyophilized Powder Fro Inectin (Iv)': 2,
#          'Solution For Injection (Iv/ Intraarterial/Intrathecal )': 2,
#          'Prolonged Release Tablet': 7,
#          'Hard Gelatin Capsule': 17,
#          'Inhalation Powder In Hard Capsule': 1,
#          'intravenous injection': 1,
#          'ORAL TABLET': 1,
#          'Concentrate Solution For Injection (Iv Infusion)': 1,
#          'Concentrated Solution For Injection (I.V.)': 1,
#          'Transdermal Gel': 3,
#          'Tablet -Film Coated': 1,
#          'Opthalmic Ointment': 2,
#          'Over-the-Counter (OTC)': 1,
#          'Ointment Tulle Dressing': 1,
#          'Solution For Inejction': 3,
#          'Concentrated Solution For Injection (Iv)': 1,
#          'Dry Powder for Inhalation': 6,
#          'Syrup Equivalent To 10 Mg Elemental Zinc)': 1,
#          'Metered Dose Inhalation': 1,
#          'Sustained Release Sterile Rod-Shaped Implant For Ophthalmic Intravitreal Injection': 1,
#          'Dry Powder Inhalation Capsule': 1,
#          'Orodispersable Tablet': 1,
#          'Sterile Otic Drops': 1,
#          'Powder for Solution for Injection (1.V.)': 1,
#          'Tablet, dispersible': 2,
#          'Oral Granules': 4,
#          'Powder For Iv Injection (IV)': 1,
#          'Topical Soln. (Mouth Paint)': 1,
#          "Sol'N For Injection (Iv)": 2,
#          'Rectal Solution (Enema)': 1,
#          'Solution for injection (IM)': 1,
#          'Modified Release Film-Coated Tablet': 3,
#          'Suspension ; Syrup': 1,
#          'Intravenous Injection': 1,
#          'sachet Gastro-Resistant Prolonged Release Granules': 4,
#          'Powder for Injection (I.V)': 1,
#          'Prolonged-Release Capsule': 10,
#          'Power for Suspension': 1,
#          'Powder For Injeciton (I.V.)': 1,
#          'Softgel Capsule For Vaginal Use': 1,
#          'Lyophilized Powder For Intravenous Infusion': 7,
#          'Lyophilized Powder for Solution for IV Injection': 1,
#          'Vial Solution': 1,
#          ...})

# %% [markdown]
# Instead, we "tokenize" the dosage forms then attempt to get the elements by tagging.

# %%
# sentence format
dosage_forms_toks = []
# word format
dosage_forms_sent = []


for k,i in enumerate(Counter(f['Dosage Form']).keys()):
    
    if pd.isnull(i):
        dosage_forms_toks += [[]]
        dosage_forms_sent += [[]]
    else:
        # split then remove special characters
        s = re.split(r'\s+|\/',i.lower())
        s = [re.sub(r'[^\w|^\-]|\d','',j) for j in s]

        # remove blanks
        s = [j for j in s if j != '']
        
        dosage_forms_toks += [s]
        dosage_forms_sent += [' '.join([j for j in s])]
        

print(len(dosage_forms_toks))
# Out:
# 2252

# %%
dosage_forms_toks[:10]
# Out:
# [['solution', 'for', 'injection', 'sc'],
#  ['suspension', 'for', 'injection', 'sc'],
#  ['lyophilized',
#   'powder',
#   'for',
#   'suspension',
#   'for',
#   'intratracheal',
#   'administration'],
#  ['solution', 'for', 'injection', 'iv', 'sc'],
#  ['solution', 'for', 'injection', 'iv', 'sc'],
#  ['solution', 'for', 'injection', 'im', 'iv', 'sc'],
#  ['suspension', 'for', 'injection', 'sc'],
#  ['suspension', 'for', 'injection'],
#  ['solution', 'for', 'injection'],
#  ['suspension', 'for', 'injection', 'sc']]

# %%
dosage_forms_sent[:10]
# Out:
# ['solution for injection sc',
#  'suspension for injection sc',
#  'lyophilized powder for suspension for intratracheal administration',
#  'solution for injection iv sc',
#  'solution for injection iv sc',
#  'solution for injection im iv sc',
#  'suspension for injection sc',
#  'suspension for injection',
#  'solution for injection',
#  'suspension for injection sc']

# %%
format_map = pd.DataFrame(columns=['original','tok_sent'])
format_map['original'] = Counter(f['Dosage Form']).keys()
format_map['tok_sent'] = dosage_forms_sent
format_map.head(10)
# Out:
#                                             original  \
# 0                        Solution For Injection (SC)
# 1                     Suspension for Injection (S.C)
# 2  Lyophilized Powder for \r\nSuspension for Intr...
# 3                 Solution for Injection (I.V./S.C.)
# 4                     Solution for Injection (IV/SC)
# 5                  Solution For Injection (Im/Iv/Sc)
# 6                      Suspension For Injection (SC)
# 7                           Suspension For Injection
# 8                             Solution for injection
# 9                      Suspension for injection (SC)
#
#                                             tok_sent
# 0                          solution for injection sc
# 1                        suspension for injection sc
# 2  lyophilized powder for suspension for intratra...
# 3                       solution for injection iv sc
# 4                       solution for injection iv sc
# 5                    solution for injection im iv sc
# 6                        suspension for injection sc
# 7                           suspension for injection
# 8                             solution for injection
# 9                        suspension for injection sc

# %% [markdown]
# # Properties
#
# We use the following properties in general to describe the drug:
#
# - **modifier**: these are special physical properties of the drug. e.g., orodispersible, extended-release, cherry-flavored, freeze-dried. These are mostly adjectives.
# - **form**: the format of the drug. Is it solid, liquid, gas, solution, emulsion, etc
# - **route**: how the drug is administered. This can be through injection, inhalation, topical application, etc. It can be specific or broad.
#
#
# We see that if we assume that the phrase is of the format:
#
# $$(\text{modifier})-(\text{form})-\text{for}-(\text{route})$$
#
# we can generally approach the problem by splitting the drug description by finding the word "for". For example, we can ideally split *sterile freeze-dried powder for iv infusion or injection* into
#
# $$\text{sterile freeze-dried} + \text{powder} + \text{for} + \text{iv infusion or injection}$$
#
# Note that both *sterile freeze-fried* and *iv infusion or injection* can be further divided by finding any nouns, adjectives, and adverbs within the subphrases.

# %% [markdown]
# ## 1. Separating the route from the dosage form
# Both subphrases can contain modifiers and nouns. Splitting the drug description early on can thus allow us to improve search performance.

# %%
def get_subphrases(phrase):
    
    # return subphrases immediate if splitting is success
    try:
        phr = re.split(r'\s+?\bfor\b\s+?', phrase, maxsplit=1)
        if len(phr)==2: return phr
    except TypeError:
        return ['', '']
    
    # check if subphrase is blank invalid or if all splits are blanks
    if phr == ['']:
        return ['', '']
    # check if phrase starts with "for"; return this as the RoA
    else:
        try:
            mat = re.search(r'(?<=for\b\s).+?$', phr[0]).group(0)
            return ['', mat]
        except (TypeError, AttributeError):
            pass
    
    # if neither, treat extracted subphrase as the other subphrase drug form
    return [phr[0], '']

# %%
format_map['drug_form_phrase'], format_map['drug_roa_phrase'] = zip(*format_map['tok_sent'].apply(get_subphrases))
format_map.head(10)
# Out:
#                                             original  \
# 0                        Solution For Injection (SC)
# 1                     Suspension for Injection (S.C)
# 2  Lyophilized Powder for \r\nSuspension for Intr...
# 3                 Solution for Injection (I.V./S.C.)
# 4                     Solution for Injection (IV/SC)
# 5                  Solution For Injection (Im/Iv/Sc)
# 6                      Suspension For Injection (SC)
# 7                           Suspension For Injection
# 8                             Solution for injection
# 9                      Suspension for injection (SC)
#
#                                             tok_sent    drug_form_phrase  \
# 0                          solution for injection sc            solution
# 1                        suspension for injection sc          suspension
# 2  lyophilized powder for suspension for intratra...  lyophilized powder
# 3                       solution for injection iv sc            solution
# 4                       solution for injection iv sc            solution
# 5                    solution for injection im iv sc            solution
# 6                        suspension for injection sc          suspension
# 7                           suspension for injection          suspension
# 8                             solution for injection            solution
# 9                        suspension for injection sc          suspension
#
#                                drug_roa_phrase
# 0                                 injection sc
# 1                                 injection sc
# 2  suspension for intratracheal administration
# 3                              injection iv sc
# 4                              injection iv sc
# 5                           injection im iv sc
# 6                                 injection sc
# 7                                    injection
# 8                                    injection
# 9                                 injection sc

# %% [markdown]
# ## 2. Extracting the drug formats

# %%
# open drug formats file and convert to regex pattern
# \b<>|<>|...\b
with open('json_data/drug_formats.json','r') as file:
    drug_formats = json.load(file)
    
# RoA delivery
roa_nouns = [r'\b(' + '|'.join(v.values()) + ')\\b' for k,v in drug_formats.items()]

# %%
def get_drug_format(subphrase):
    
    drug_format = None
    for roa in roa_nouns:
        try:
            drug_format = re.search(roa, subphrase).group(0)
        except (TypeError, AttributeError):
            continue
    
    return drug_format

# %%
format_map['form_format'] = format_map['drug_form_phrase'].apply(get_drug_format)
format_map['roa_format'] = format_map['drug_roa_phrase'].apply(get_drug_format)
format_map.head(10)
# Out:
#                                             original  \
# 0                        Solution For Injection (SC)
# 1                     Suspension for Injection (S.C)
# 2  Lyophilized Powder for \r\nSuspension for Intr...
# 3                 Solution for Injection (I.V./S.C.)
# 4                     Solution for Injection (IV/SC)
# 5                  Solution For Injection (Im/Iv/Sc)
# 6                      Suspension For Injection (SC)
# 7                           Suspension For Injection
# 8                             Solution for injection
# 9                      Suspension for injection (SC)
#
#                                             tok_sent    drug_form_phrase  \
# 0                          solution for injection sc            solution
# 1                        suspension for injection sc          suspension
# 2  lyophilized powder for suspension for intratra...  lyophilized powder
# 3                       solution for injection iv sc            solution
# 4                       solution for injection iv sc            solution
# 5                    solution for injection im iv sc            solution
# 6                        suspension for injection sc          suspension
# 7                           suspension for injection          suspension
# 8                             solution for injection            solution
# 9                        suspension for injection sc          suspension
#
#                                drug_roa_phrase form_format  roa_format
# 0                                 injection sc    solution        None
# 1                                 injection sc  suspension        None
# 2  suspension for intratracheal administration      powder  suspension
# 3                              injection iv sc    solution        None
# 4                              injection iv sc    solution        None
# 5                           injection im iv sc    solution        None
# 6                                 injection sc  suspension        None
# 7                                    injection  suspension        None
# 8                                    injection    solution        None
# 9                                 injection sc  suspension        None

# %%
format_map.to_csv('maps/format_map.csv',index=False)

# %% [markdown]
# ## 3. Modifiers
# Getting the modifiers is a bit different. For the first subphrase (`drug_form_subphrase`), it is rather straightforward and may be just as simple as scanning for a list of words preceding the extracted nouns from step 2. However, routes of administration (`drug_roa_subphrase`) have an additional level of detail.

# %% [markdown]
# ### a. Routes of administration
#
# A drug can be described by how it is administered (e.g., orally, gargled, by injection), and if so again, *how*.

# %%
# RoA adjectives
roa_adjs = [r'\b(im|iv|id|ia|sc|ivt)\b', r'\b(intra\-?\w+?\b)', r'\b(\w+?ic)\b', r'\b(in\-ovo)\b'
            r'\b(subcut.*?|epidur.*?)\b', r'\b(\w+?al)\b(?!\s+?free$)', r'\b(dilu.*?|reconsti.*?)\b']

# RoA nouns (action verbs)
roa_actions = [r'\b(inf(?:usion)?|inj(?:ection)?|inhal(?:ation)|instillation)\b',
               r'\b(gargl(?:ing|e)|nebuliz(?:ation|ing)?|sus(?:pension)?)\b',
               r'\b(filt(?:ering|ration))\b']

# %%
def get_roa_details(phrase):
    
    # capture one word before "for" just in case
    # try:
    #    roa_phrase = re.search(r'\bfor\b.+?$', phrase).group(0)
    #except (TypeError, AttributeError):
    #    roa_phrase = None
    
    
    # get all RoA descriptors
    roa_path = None
    roa_technique = None
    
    if True: # roa_phrase is not None:
        roa_path = []
        for roa in roa_adjs:
            r = re.findall(roa, phrase)
            roa_path += r
        roa_path = list(set(roa_path))
        
        roa_technique = []
        for roa in roa_actions:
            r = re.findall(roa, phrase)
            roa_technique += r
        roa_technique = list(set(roa_technique))
    
    
    return roa_path, roa_technique

# %%
format_map['roa_detail_1'], format_map['roa_detail_2'] = zip(*format_map['drug_roa_phrase'].apply(get_roa_details))
format_map.head(10)
# Out:
#                                             original  \
# 0                        Solution For Injection (SC)
# 1                     Suspension for Injection (S.C)
# 2  Lyophilized Powder for \r\nSuspension for Intr...
# 3                 Solution for Injection (I.V./S.C.)
# 4                     Solution for Injection (IV/SC)
# 5                  Solution For Injection (Im/Iv/Sc)
# 6                      Suspension For Injection (SC)
# 7                           Suspension For Injection
# 8                             Solution for injection
# 9                      Suspension for injection (SC)
#
#                                             tok_sent    drug_form_phrase  \
# 0                          solution for injection sc            solution
# 1                        suspension for injection sc          suspension
# 2  lyophilized powder for suspension for intratra...  lyophilized powder
# 3                       solution for injection iv sc            solution
# 4                       solution for injection iv sc            solution
# 5                    solution for injection im iv sc            solution
# 6                        suspension for injection sc          suspension
# 7                           suspension for injection          suspension
# 8                             solution for injection            solution
# 9                        suspension for injection sc          suspension
#
#                                drug_roa_phrase form_format  roa_format  \
# 0                                 injection sc    solution        None
# 1                                 injection sc  suspension        None
# 2  suspension for intratracheal administration      powder  suspension
# 3                              injection iv sc    solution        None
# 4                              injection iv sc    solution        None
# 5                           injection im iv sc    solution        None
# 6                                 injection sc  suspension        None
# 7                                    injection  suspension        None
# 8                                    injection    solution        None
# 9                                 injection sc  suspension        None
#
#       roa_detail_1  roa_detail_2
# 0             [sc]   [injection]
# 1             [sc]   [injection]
# 2  [intratracheal]  [suspension]
# 3         [sc, iv]   [injection]
# 4         [sc, iv]   [injection]
# 5     [im, sc, iv]   [injection]
# 6             [sc]   [injection]
# 7               []   [injection]
# 8               []   [injection]
# 9             [sc]   [injection]

# %%
format_map.to_csv('maps/format_map.csv',index=False)

# %% [markdown]
# ### b. Physical format
#
# This refers to the physical properties of the drug. We will use another `json` file for this.
